# %% [markdown]
# ### An attempt at using jupyter notebook :)
# I think I am succeeding. Also GitHub is cooperating with me and I believe I have uploaded this correctly!

# %%
print("hello world")
# Out:
# hello world

# %%
from IPython import display
display.Image("https://www.shemazing.net/wp-content/uploads/2016/07/taylor-swift--photo-bustle1-656x457.jpeg")
